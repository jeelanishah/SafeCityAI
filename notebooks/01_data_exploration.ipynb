# %% [markdown]
# # Data Exploration
#
# Explore SafeCityAI dataset statistics and visualizations.

# %%
import sys
sys.path.append('..')

from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from src.data_utils import YOLODataset

dataset_dir = Path('../data/processed')
train_dataset = YOLODataset(dataset_dir / 'train' / 'images', dataset_dir / 'train' / 'labels')
print(f'Train dataset size: {len(train_dataset)}')
