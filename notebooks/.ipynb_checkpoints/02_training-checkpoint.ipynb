# %% [markdown]
# # Model Training
#
# Train YOLOv5 on SafeCityAI dataset.

# %%
from ultralytics import YOLO

model = YOLO('yolov5s.pt')
results = model.train(data='../data/data.yaml', epochs=100, imgsz=640)
