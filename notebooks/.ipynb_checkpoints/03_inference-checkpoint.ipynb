# %% [markdown]
# # Inference Examples
#
# Run inference on test images.

# %%
import sys
sys.path.append('..')

from src.inference import load_model
from pathlib import Path

model = load_model(Path('../models/weights/best.pt'))
result = model.predict('../data/processed/test/images/sample.jpg')
print(f'Found {len(result["detections"])} detections')
